# %% [markdown]
# Kalau `if-else` itu soal **"Memilih Jalur"**, maka `for` dan `while` itu soal **"Otomatisasi Jalur"**. Di dunia Data Analyst, ini adalah mesin buat lo nge-proses ribuan baris data tanpa ngetik manual satu-satu.
#
# ---
#
# ## 🏗️ Core Architecture: The Looping Theories
#
# Dalam Python, ada dua cara buat bikin perulangan, dan masing-masing punya "kepribadian" yang beda total:
#
# ### 🎡 1. The Fixed-Trip Theory (`for` loop)
# Ini adalah perulangan yang **"Pasti-Pasti Aja"**. Lo tahu dari awal berapa kali lo mau jalan, atau berapa banyak item yang mau lo proses.
# * **Karakteristik:** Terukur, Berhingga, dan Statis.
# * **Analogi:** Seperti bis jemputan karyawan yang berhenti di setiap halte yang sudah ada di daftar rute. Kalau halte habis, bis berhenti.
# * **Kapan Pakai:** Saat lo punya list data (List, Tuple, String) atau rentang angka yang jelas.
#
#
#
# ---
#
# ### 🌪️ 2. The Conditional Cyclone (`while` loop)
# Ini adalah perulangan yang **"Tergantung Situasi"**. Lo nggak tahu kapan bakal berhenti, pokoknya selama syarat masih `True`, hajar terus!
# * **Karakteristik:** Dinamis, Berbahaya (bisa bikin *infinite loop*), dan Bergantung pada kondisi.
# * **Analogi:** Seperti kipas angin otomatis. Dia bakal muter terus **SELAMA** suhu ruangan di atas 30 derajat. Begitu suhu turun, baru dia stop.
# * **Kapan Pakai:** Saat lo menunggu input user, menunggu sensor, atau mencari sesuatu yang lo nggak tahu ada di urutan ke berapa.
#
#
#
# ---
#
# ## 📑 Perbandingan Arsitektur (Summary)
#
# | Fitur | **`for` loop** | **`while` loop** |
# | :--- | :--- | :--- |
# | **Fokus** | **Iterasi** (Mengunjungi setiap item). | **Kondisi** (Berjalan selama syarat terpenuhi). |
# | **Kontrol** | Otomatis (Berhenti di item terakhir). | Manual (Lo harus ubah variabel syarat di dalem). |
# | **Resiko** | Rendah (Hampir selalu berhenti). | Tinggi (Bisa bikin laptop nge-hang kalau lupa distop). |
#
# ---
#
# ## 🛠️ The "Universal Controller": Break & Continue
#
# Ini adalah dua tombol darurat yang bisa lo pasang di dalem `for` maupun `while`:
#
# 1. **`break` (The Emergency Stop):** Paksa berhenti sekarang juga, keluar dari perulangan, bodo amat sama sisa antrean.
# 2. **`continue` (The Skip Button):** Lewatin item yang ini aja, langsung loncat ke item berikutnya.
#
# ---
#
# ### 💡 SOP Persiapan Sebelum Belajar Loop:
#
# Sebelum kita gas ke kode di chat berikutnya, pastiin lo udah paham ini:
# 1. **Loop itu butuh `iterable`:** Sesuatu yang bisa dihitung (kayak isi folder, baris di Excel, atau urutan angka).
# 2. **Indentasi tetap Raja:** Sama kayak `if`, isi di dalem loop harus menjorok ke dalem.
# 3. **Infinite Loop Warning:** Di `while`, selalu pastiin ada cara buat bikin kondisinya jadi `False` di akhir, kalau nggak CPU lo bakal teriak.
#
# Udah siap gue kasih contoh kode "Decision Matrix" yang digabung sama perulangan buat lo masukin ke Notebook? Mau mulai dari `for` yang stabil atau `while` yang liar dulu?

# %% [markdown]
# Nah, biar makin paham soal **Indentasi** dan **Iterable**, ayo kita masuk ke praktek **`for` loop**. Gue buatin rangkumannya buat lo simpen di sel baru `.ipynb` lo.
#
# ---
#
# ```markdown
# # 🎡 The Fixed-Trip Theory: for Loop
#
# `for` loop digunakan ketika kita ingin mengeksekusi blok kode untuk **setiap item** dalam sebuah koleksi (Iterable).
#
# ### 🏗️ Struktur Dasar
# ```python
# # for [nama_variabel_sementara] in [iterable]:
# #     [kode_anak_buah_yang_diulang]
#
# transaksi = [5000, 2500, 10000]
#
# for angka in transaksi:
#     print(f"Memproses transaksi sebesar: {angka}")
#     # Indentasi di sini berarti baris ini milik si 'for'
# ```

# %% [markdown]
# Oke, mari kita beresin tiga fondasi ini dulu sebelum lo mulai ngetik kode loop. Karena kalau tiga hal ini belum "klik", nanti lo bakal sering ketemu error yang bikin pusing.
#
# ---
#
# ## 📦 1. Apa itu Iterable? (Bukan Cuma Hitungan)
#
# Bener, hitungan itu salah satunya. Tapi secara teknis, **Iterable** adalah **"Segala sesuatu yang bisa lo preteli satu-satu"**.
#
# Bayangkan sebuah kontainer. Kalau lo bisa ngambil isinya satu demi satu, itu namanya Iterable.
#
# * **List/Array:** `[10, 20, 30]` → Lo ambil 10, lalu 20, lalu 30. (**Iterable**)
# * **String:** `"FAUZY"` → Lo ambil 'F', lalu 'A', lalu 'U', dan seterusnya. (**Iterable**)
# * **Range:** `range(1, 5)` → Urutan angka 1 sampai 4. (**Iterable**)
# * **Integer Tunggal:** `100` → Lo nggak bisa preteli angka 100. Ini cuma satu nilai utuh. (**Bukan Iterable**).
#
# > **Comprehend:** Loop itu kayak kurir. Dia butuh **alamat tujuan** (Iterable) buat nganter paketnya. Kalau alamatnya cuma satu titik tanpa urutan, kurirnya bingung mau muter ke mana.
#
# ---

# %% [markdown]
# ## 🏗️ 2. Indentasi (The Border Theory)
#
# Di Python, **Indentasi** (spasi di awal baris) bukan cuma buat rapi-rapian. Itu adalah **"Pagar Wilayah"**. Python nggak pake kurung kurawal `{}` kayak bahasa lain, dia cuma liat spasi.
#
# * **Aturan Main:** Semua kode yang menjorok ke dalam (biasanya 4 spasi atau 1 Tab) dianggap sebagai **"Anak Buah"** dari baris yang ada di atasnya.
#
#
#
# **Analogi Ruangan:**
# ```python
# if hari == "hujan": # <-- Tuan Rumah
#     bawa_payung = True # <-- Di dalam ruangan (Anak buah if)
#     pakai_jas_hujan = True # <-- Di dalam ruangan (Anak buah if)
# # -----------------------
# print("Selesai") # <-- Di luar ruangan (Gak peduli hujan atau nggak, ini pasti jalan)
# ```
#
# **Kesalahan Fatal:** Kalau lo lupa indentasi, Python bakal teriak `IndentationError`. Kalau lo salah naruh indentasi (ketinggian atau kerendahan), logika lo bakal **bocor** (kode yang harusnya jalan cuma pas hujan, malah jalan terus).
#
# ---
#
# ## 🌪️ 3. Infinite Loop (The Loop of Doom)
#
# Lo bener, ini emang nyata dan sering terjadi di `while` loop. Ini terjadi ketika **Syarat Berhenti** nggak pernah tercapai.
#
# **Analogi Kipas Angin Rusak:**
# Lo nyuruh kipas muter: *"Muter terus SELAMA suhu > 30"*.
# Tapi lo lupa masang alat buat nurunin suhu di dalem perulangannya. Hasilnya? Suhu tetep 35, dan kipas muter selamanya sampai laptop lo panas atau baterai abis.
#
#
#
# **Contoh Code yang Bahaya:**
# ```python
# baterai = 100
# while baterai > 0:
#     print("Main Game...")
#     # LUPA NULIS: baterai = baterai - 1
#     # Hasilnya: baterai tetep 100 selamanya. INFINITE LOOP!
# ```
#
# ---
#
# ## 📑 Cara "Sembuh" dari Infinite Loop di Mac
#
# Kalau nanti pas lo nyoba `while` tiba-tiba laptop lo bunyi kipasnya kenceng dan terminal nggak berhenti-berhenti ngirim teks:
# 1. **Di Terminal/VS Code:** Tekan **`Control + C`** (Ini tombol *Emergency Stop* buat matiin proses yang lagi jalan).
# 2. **Di Jupyter Notebook:** Klik tombol **Stop (Ikon Kotak)** di toolbar atas atau tekan **`I, I`** (dua kali `I`) buat *Interrupt Kernel*.
#
# ---

# %% [markdown]
# 🟢 Test Case 1: Filter List "Nilai Lulus"
# Fokus: Memahami Iterable (List) dan Indentasi (Pagar Wilayah).
#
# Skenario: Lo punya list nilai. Lo cuma mau memproses angka yang >= 75.
#
# Tujuan: Memastikan lo nggak salah naruh print, supaya yang nggak lulus nggak ikut muncul.

# %% [markdown]
# ---
#
# ### 🪆 1. Iterasi pada String (Preteli Karakter)
# String adalah kumpulan karakter. Kita bisa nge-loop setiap hurufnya.
#
# ```python
# nama = "FAUZY"
# for huruf in nama:
#     print(f"Huruf: {huruf}")
# ```
#
# ### 🔢 2. Iterasi dengan Angka (Fungsi `range()`)
# Kalau lo mau ngulang sesuatu sebanyak `X` kali tanpa punya list-nya, lo pake `range()`.
# * `range(5)` → bakal jalan 5 kali (mulai dari 0 sampai 4).
#
# ```python
# for i in range(3):
#     print(f"Pengecekan ke-{i+1}")
# ```
#
# ---
#
# ## 🏗️ Logic Inside Loop (The Decision Matrix Combo)
# Di sinilah ilmu **Indentasi** lo diuji. Kita bisa masukin `if` di dalem `for`.
#
# **Skenario:** Lo mau nge-filter transaksi mana yang "Mencurigakan" (di atas 7000).
#
# ```python
# daftar_transaksi = [5000, 2500, 12000, 3000, 9500]
#
# for nominal in daftar_transaksi:
#     # --- LEVEL 1 INDENTASI (Anak buah for) ---
#     if nominal > 7000:
#         # --- LEVEL 2 INDENTASI (Anak buah if yang ada di dalem for) ---
#         print(f"⚠️ ALERT: Transaksi {nominal} terlalu besar!")
#     else:
#         print(f"✅ Aman: {nominal}")
#
# print("--- Proses Selesai ---") # Luar indentasi = Jalan cuma sekali di akhir
# ```
#
#
#
# ---
#
# ## 📑 SOP Menulis Loop yang Rapi
#
# 1.  **Siapkan Iterable:** Pastikan data lo bisa "dipreteli" (List, String, atau Range).
# 2.  **Variabel Sementara:** Kasih nama yang masuk akal. Kalau list-nya `transaksi`, variabel sementaranya `nominal`. Kalau list-nya `users`, panggil `user`.
# 3.  **Jaga Pagar Indentasi:**
#     * Satu kali masuk (4 spasi) = Jalan setiap kali loop muter.
#     * Dua kali masuk = Jalan cuma kalau `if` di dalem loop bernilai `True`.
#     * Sejajar dengan `for` = Jalan cuma sekali setelah loop bener-bener beres.
#
# ---
#
# ### 🏆 Challenge Buat Lo (Coba tulis di sel bawahnya):
# Coba buat list angka `[1, 2, 3, 4, 5, 6]`.
# Terus pake `for` loop dan `if` buat nge-print:
# * "Ganjil" kalau angkanya ganjil.
# * "Genap" kalau angkanya genap.
#
# *(Petunjuk: Pake operator modulo `% 2 == 0` buat cek genap)*.
#
# Udah aman soal indentasi di `for` ini? Mau lanjut bedah "bahaya"-nya `while` loop sekarang?

# %%
nilai_siswa = [60, 85, 90, 70,75,82,55]

for nilai in nilai_siswa:
    if nilai >=75:
        print(f"Nilai {nilai} dinyatakan Lulus")
# Out:
# Nilai 85 dinyatakan Lulus
# Nilai 90 dinyatakan Lulus
# Nilai 75 dinyatakan Lulus
# Nilai 82 dinyatakan Lulus

# %% [markdown]
# Belajar make real data ibaratkan kita adalah BA dan kita load Data

# %%
import pandas as pd

# Kita bikin data mentahnya dulu
data = {
    'Nama Produk': ['Laptop Gaming', 'Mouse Wireless', 'Keyboard Mechanical', 'Monitor 4K', 'Kabel HDMI'],
    'Harga': [15000000, 150000, 800000, 3500000, 50000],
    'Stok': [3, 15, 2, 10, 0]
}

# Kita ubah jadi Tabel (DataFrame)
df = pd.DataFrame(data)

# Kita simpan jadi file Excel beneran
df.to_excel('data_toko.xlsx', index=False)

print("✅ File 'data_toko.xlsx' berhasil dibuat di folder lo!")
# Out:
# ✅ File 'data_toko.xlsx' berhasil dibuat di folder lo!

# %%
import pandas as pd

#Baca file Excel yang sudah kita buat
df = pd.read_excel('data_toko.xlsx')
data_toko = df.to_dict('records')

# Buat Variable Penampung (Counter)
total_modal_stok = 0
produk_kritis = []

print("📊 Analisis Data Toko 📊")
# Out:
# 📊 Analisis Data Toko 📊

# %% [markdown]
# *Kita pakai pendekatan "Forensik Data". Anggap aja data yang baru lo load dari Excel itu "kotak misteri". Sebelum lo olah pake loop, lo harus intip isinya pake 3 perintah dasar ini.*
#
# ### 🔍 Tahap 1: Inpeksi Visual (Liat Barangnya)
# - Setelah lo jalanin pd.read_excel, jangan langsung ngetik kode panjang. Cek dulu apakah datanya beneran masuk.

# %%
# Cek 5 baris pertama (Biar gak menuhi layar kalau datanya ribuan)
print(df.head())
# Out:
#            Nama Produk     Harga  Stok
# 0        Laptop Gaming  15000000     3
# 1       Mouse Wireless    150000    15
# 2  Keyboard Mechanical    800000     2
# 3           Monitor 4K   3500000    10
# 4           Kabel HDMI     50000     0

# %%
# Cek kolom apa aja yang ada (Biar gak salah ketik nama kolom)
print(df.columns)
# Out:
# Index(['Nama Produk', 'Harga', 'Stok'], dtype='object')

# %% [markdown]
# #### 🔬 Tahap 2: Cek Tipe Data (Iterable atau Bukan?)
# - Ini yang kita bahas tadi. Lo harus tau si df ini makhluk apa.

# %%
# Cek tipe struktur besarnya
print(type(df))
# Output: <class 'pandas.core.frame.DataFrame'>
# (Ini ibarat Tabel Utuh)

# Cek tipe data tiap kolom
print(df.dtypes)
# Ini penting! Lo bakal tau mana yang Angka (int/float)
# dan mana yang Teks (object).
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Nama Produk    object
# Harga           int64
# Stok            int64
# dtype: object

# %%
# List Penampung Suplier
memo_orders = []

for barang in data_toko:

    if barang["Stok"] < 5:
        pesan = f"Segera Pesan {barang['Nama Produk']}! , Terakhir dijual harga Rp. {barang['Harga']} , {barang['Stok']} stok tersisa."
        memo_orders.append(pesan)

# List Restock Purchasing
print("--- List Restock Purchasing ---")
for tugas in memo_orders:
    print(f"List Restock: {tugas}")
# Out:
# --- List Restock Purchasing ---
# List Restock: Segera Pesan Laptop Gaming! , Terakhir dijual harga Rp. 15000000 , 3 stok tersisa.
# List Restock: Segera Pesan Keyboard Mechanical! , Terakhir dijual harga Rp. 800000 , 2 stok tersisa.
# List Restock: Segera Pesan Kabel HDMI! , Terakhir dijual harga Rp. 50000 , 0 stok tersisa.

# %% [markdown]
# Jawabannya: Bisa di-loop, tapi bukan karena dia int64.
#
# #### 🧠 1. Bedakan "Isi" dan "Wadah"
#
# - int64 (Harga/Stok): Ini adalah tipe data Isinya. Seperti yang kita bahas, satu angka 15000000 itu Non-Iterable (nggak bisa dipreteli).
#
# - Kolom (Series): Ini adalah Wadahnya. Satu kolom "Harga" di Excel itu adalah sebuah List/Series. Nah, wadah inilah yang Iterable.
#
# *Analogi:*
# Lo nggak bisa mempreteli satu butir telur (int). Tapi lo bisa mempreteli satu baris karton telur (Kolom/Series).

# %% [markdown]
# ##### 🌪️ Praktek: While Loop + Input User
#
# Coba lo salin dan jalanin kode ini di sel baru. Program ini bakal jalan terus selama user nggak ngetik 'keluar'.

# %%
# 1. Siapkan variabel syarat
perintah = ""

print("--- Selamat Datang di Sistem Cek Stok ---")

# 2. Syarat perulangan: Selama perintah bukan 'keluar'
while perintah.lower() != "keluar":
    perintah = input("Ketik 'cek' untuk lihat barang, atau 'keluar' untuk berhenti: ")

    if perintah.lower() == "cek":
        # Kita panggil data dari loop sebelumnya
        for barang in data_toko:
            print(f"- {barang['Nama Produk']}: {barang['Stok']} pcs")
    elif perintah.lower() == "keluar":
        print("Sistem dimatikan. Sampai jumpa!")
    else:
        print("Perintah nggak dikenal, bro.")
# Out:
# --- Selamat Datang di Sistem Cek Stok ---
# - Laptop Gaming: 3 pcs
# - Mouse Wireless: 15 pcs
# - Keyboard Mechanical: 2 pcs
# - Monitor 4K: 10 pcs
# - Kabel HDMI: 0 pcs
# Perintah nggak dikenal, bro.
# Perintah nggak dikenal, bro.
# Sistem dimatikan. Sampai jumpa!

# %% [markdown]
# Kode yang **"nggak aman"** itu ibarat mobil yang gasnya dipantek tapi remnya blong. Di dunia coding, ini disebut **Infinite Loop**.
#
# Sesuai catatan lo tentang **"The Loop of Doom"**, kode jadi nggak aman kalau **Syarat Berhenti** nggak pernah tercapai. Berikut adalah 3 cara paling umum buat bikin laptop lo "meledak" lagi:
#
# ---
#
# ### 1. Lupa Update "Counter" (Rem Blong)
# Ini kesalahan paling klasik. Lo punya syarat, tapi lo lupa nulis kode buat ngerubah angka syarat itu.
#
# ```python
# stok = 5
# while stok > 0:
#     print(f"Stok masih ada: {stok}")
#     # DI SINI HARUSNYA ADA: stok = stok - 1
#     # Tapi karena lo lupa, stok bakal tetep 5 selamanya.
#     # 5 > 0 itu SELALU TRUE.
# ```
# * **Efeknya:** Python bakal nge-print teks itu jutaan kali per detik sampe terminal lo nge-freeze.
#
#
# ---

# %%
stok = 5
while stok > 0:
    print(f"Memproses data... Sisa antrean: {stok}")
    stok -= 1 # Cara singkat nulis stok = stok - 1

print("✅ Semua data beres diolah!")
# Out:
# Memproses data... Sisa antrean: 5
# Memproses data... Sisa antrean: 4
# Memproses data... Sisa antrean: 3
# Memproses data... Sisa antrean: 2
# Memproses data... Sisa antrean: 1
# ✅ Semua data beres diolah!

# %% [markdown]
# Tepat banget! Logika lo udah bener 100%.
#
# Kalau lo nggak nulis `stok = stok - 1`, si Python bakal terjebak di putaran pertama selamanya. Dia bakal lapor: *"Sisa antrean: 5"*, lalu nanya lagi, *"Eh, stok masih 5 kan? Masih > 0? Oke, print lagi: Sisa antrean 5"*. Itu yang bikin terminal lo penuh sama angka 5 yang nggak berhenti-berhenti.
#
# ---
#
# ### 📉 Visualisasi: Dari "Stuck" Jadi "Selesai"
#
# Biar makin mantap di Notebook lo, ini beda cara kerja "otak" Python pas dapet perintah itu:
#
# **1. Tanpa Pengurang (Infinite Loop):**
# * **Check:** Apakah $5 > 0$? → **Ya**.
# * **Action:** Print "Sisa 5".
# * **Check:** Apakah $5 > 0$? → **Ya**.
# * **Action:** Print "Sisa 5".
# * *(Ulangi sampai kiamat)*
#
# **2. Dengan Pengurang (`stok -= 1`):**
# * **Check:** Apakah $5 > 0$? → **Ya**.
# * **Action:** Print "Sisa 5", terus **stok jadi 4**.
# * **Check:** Apakah $4 > 0$? → **Ya**.
# * **Action:** Print "Sisa 4", terus **stok jadi 3**.
# * ...
# * **Check:** Apakah $0 > 0$? → **TIDAK**.
# * **Action:** **STOP.**
#
#
#
# ---
#
# ### 💡 Analogi Terakhir: Lampu Merah
# Bayangin `while` itu lampu merah di jalanan:
# * **Syarat:** "Selama lampu merah menyala, mobil berhenti."
# * **Kondisi Gak Aman:** Lampunya rusak, merah terus nggak pernah ganti hijau. Mobil bakal antre (loop) selamanya.
# * **Kondisi Aman:** Ada timer (pengurang). Setiap detik berkurang, sampai akhirnya timer habis, lampu jadi hijau (False), dan mobil bisa jalan (Loop selesai).
#
# ---
#
# ### 🏆 Kesimpulan Sesi Malam Ini
# Lo udah paham tiga hal paling fundamental di Python hari ini:
# 1.  **For Loop:** Buat ngurus data yang jumlahnya udah pasti (kayak baris di Excel lo).
# 2.  **While Loop:** Buat nungguin kondisi sampai terpenuhi (interaktif).
# 3.  **Update Variable:** "Rem" wajib supaya laptop nggak meledak.
#
# Gimana bro? Ada bagian dari file **`II Perulangan For & While.ipynb`** lo yang mau lo edit atau tambahin lagi sebelum kita tutup sesi "ngoding" malam ini?

# %% [markdown]
# ### 2. Arah Update-nya Salah (Makin Menjauh)
# Lo nulis kodenya, tapi logikanya kebalik. Bukannya mendekati angka berhenti, malah makin menjauh.
#
# ```python
# angka = 1
# while angka < 10:
#     print(f"Angka sekarang: {angka}")
#     angka = angka - 1  # Bukannya ditambah biar jadi 10, malah dikurang!
# ```
# * **Efeknya:** Angka bakal jadi 0, -1, -2, -3... dan seterusnya. Karena angka negatif akan **selalu lebih kecil dari 10**, perulangan ini nggak bakal pernah stop.
#
# ---
#
# ### 3. Syarat yang Mustahil (The Impossible Mission)
# Lo bikin syarat yang secara logika nggak mungkin jadi `False`.
#
# ```python
# while True:
#     print("Gue lari terus tanpa nunggu siapa-siapa!")
# ```
# * **Efeknya:** Karena `True` selamanya adalah `True`, loop ini nggak punya "pintu keluar". Satu-satunya cara matiin cuma pake **`Control + C`** atau **Restart Kernel**.
#
# ---
#
# ### 📑 Cara Identifikasi "Kode Gak Aman" Sebelum di-Run:
# Sebelum lo teken tombol *Run*, coba tanya diri sendiri:
# * **"Apakah ada baris kode yang bakal ngerubah kondisi `while`?"** (Contoh: `stok -= 1`).
# * **"Apakah arah perubahannya bener?"** (Bukan malah makin jauh dari syarat stop).
# * **"Ada `input()`-nya nggak?"** Kalau ada `input()`, program bakal nunggu lo, jadi otomatis aman dari lari sendirian.
#
#
#
# Udah paham kan kenapa tadi MacBook lo langsung teriak pas kena yang nomor 3? Mau coba bikin `while` loop yang **aman** buat ngitung total diskon dari `data_toko.xlsx` lo?
